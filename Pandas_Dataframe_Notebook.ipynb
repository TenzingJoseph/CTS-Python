# %% [markdown]
# <a href="https://colab.research.google.com/github/TenzingJoseph/CTS-Python/blob/main/Pandas_Dataframe_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# ## DataFrames

# %%
students = ['Alice', 'Bob', 'Emily', 'Charlie']

# %%
scores = [90, 80, 65, 50]

# %%
exam_results = pd.DataFrame(
    {
        "name": students,
        "scores": scores
    }
)

# %%
exam_results
# Out:
#       name  scores
# 0    Alice      90
# 1      Bob      80
# 2    Emily      65
# 3  Charlie      50

# %% [markdown]
# ### Searching (SQL SELECT)

# %%
exam_results.loc[0, 'scores']
# Out:
# 90

# %%
exam_results.loc[:, 'scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: scores, dtype: int64

# %%
exam_results.loc[2, :]
# Out:
# name      Emily
# scores       65
# Name: 2, dtype: object

# %%
exam_results['scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: scores, dtype: int64

# %%
exam_results[['name', 'scores']]
# Out:
#       name  scores
# 0    Alice      90
# 1      Bob      80
# 2    Emily      65
# 3  Charlie      50

# %% [markdown]
# ### Add Columns

# %% [markdown]
# We can also easily add columns

# %%
gender = ['female', 'male', 'female', 'male']

# %%
exam_results['gender'] = gender

# %%
exam_results
# Out:
#       name  scores  gender
# 0    Alice      90  female
# 1      Bob      80    male
# 2    Emily      65  female
# 3  Charlie      50    male

# %%
exam_results['scores']
# Out:
# 0    90
# 1    80
# 2    65
# 3    50
# Name: scores, dtype: int64

# %% [markdown]
# ### Remove Columns

# %%
exam_results.drop('name', axis=1)
# Out:
#    scores  gender
# 0      90  female
# 1      80    male
# 2      65  female
# 3      50    male

# %% [markdown]
# ### Column names and Row Index

# %%
exam_results.columns
# Out:
# Index(['name', 'scores', 'gender'], dtype='object')

# %%
exam_results.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ### Renaming Columns

# %%
exam_results.rename({'name': 'first_name'}, axis=1)
# Out:
#   first_name  scores  gender
# 0      Alice      90  female
# 1        Bob      80    male
# 2      Emily      65  female
# 3    Charlie      50    male

# %% [markdown]
# ### Dealing with missing values

# %% [markdown]
# Dataframes have specific commands which help with the handling of missing data

# %%
sparse = pd.DataFrame({'a': [1, 2, 3],
                       'b': [np.nan, 4, np.nan],
                       'c': [5, np.nan, np.nan]})

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.isna()
# Out:
#        a      b      c
# 0  False   True  False
# 1  False  False   True
# 2  False   True   True

# %%
sparse.fillna(0)
# Out:
#    a    b    c
# 0  1  0.0  5.0
# 1  2  4.0  0.0
# 2  3  0.0  0.0

# %%
sparse.dropna(axis=1)
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %% [markdown]
# ### Group by

# %%
exam_results.groupby('gender').mean()
# Out:
#         scores
# gender
# female    77.5
# male      65.0

# %%
mylist = [1,2,1,2]

exam_results.groupby(mylist).get_group(1)
# Out:
#     name  scores  gender
# 0  Alice      90  female
# 2  Emily      65  female

# %%
exam_results.groupby(mylist).get_group(2)
# Out:
#       name  scores gender
# 1      Bob      80   male
# 3  Charlie      50   male

# %% [markdown]
# Thus, suppose we want to group people who obtained marks above or below 70, then we could do:

# %%
above_70 = exam_results['scores'] > 70
above_70
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: scores, dtype: bool

# %% [markdown]
# This will compute the mean scores of students who scored above or below 70

# %%
exam_results.groupby(above_70).mean()
# Out:
#         scores
# scores
# False     57.5
# True      85.0

# %% [markdown]
# ### Merge and Joining

# %%
contacts = pd.DataFrame(
    {
        'name' : ['Alice', 'Charlie'],
        'tel'  : ['+44 1234 5678', '+44 3245 5564']
    }
)

# %%
exam_results.merge(contacts, left_on='name', right_on='name')   # defaults to inner join
# Out:
#       name  scores  gender            tel
# 0    Alice      90  female  +44 1234 5678
# 1  Charlie      50    male  +44 3245 5564

# %%
exam_results.merge(contacts, left_on='name', right_on='name', how='outer')
# Out:
#       name  scores  gender            tel
# 0    Alice      90  female  +44 1234 5678
# 1      Bob      80    male            NaN
# 2    Emily      65  female            NaN
# 3  Charlie      50    male  +44 3245 5564
